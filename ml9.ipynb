# %%
#Theory
"""
1. Can we use Bagging for regression problems?

Yes, Bagging can be used for regression. Instead of majority voting, it takes the average of predictions.

2. What is the difference between multiple model training and single model training?
Single model → only one model is trained
Multiple model → many models are trained and combined for better performance

3. Explain the concept of feature randomness in Random Forest

Random Forest selects random features for each tree, which helps reduce overfitting and improves performance.

4. What is OOB (Out-of-Bag) Score?

OOB score is a way to evaluate the model using data that was not used during training.

5. How can you measure the importance of features in a Random Forest model?

By checking how much each feature contributes to prediction using feature importance scores.

6. Explain the working principle of a Bagging Classifier

It trains multiple models on different random samples of data and combines their predictions.

7. How do you evaluate a Bagging Classifier’s performance?

Using metrics like accuracy, precision, recall, F1-score.

8. How does a Bagging Regressor work?

It trains multiple models and takes the average of their predictions.

9. What is the main advantage of ensemble techniques?

Better accuracy and reduced overfitting.

10. What is the main challenge of ensemble methods?

They are complex and take more time to train.

11. Explain the key idea behind ensemble techniques

Combine multiple models to get better results than a single model.

12. What is a Random Forest Classifier?

It is an ensemble model that uses many decision trees for classification.

13. What are the main types of ensemble techniques?
Bagging
Boosting
Stacking

14. What is ensemble learning in machine learning?

Using multiple models together to improve performance.

15. When should we avoid using ensemble methods?

When data is small or when we need simple and fast models.

16. How does Bagging help in reducing overfitting?

It reduces variance by averaging multiple models.

17. Why is Random Forest better than a single Decision Tree?

Because it reduces overfitting and gives more stable results.

18. What is the role of bootstrap sampling in Bagging?

It creates different random datasets for training each model.

19. What are some real-world applications of ensemble techniques?
Fraud detection
Recommendation systems
Medical diagnosis

20. What is the difference between Bagging and Boosting?
Bagging → models trained independently
Boosting → models trained sequentially (focus on errors)
"""
# Out:
# '\n1. Can we use Bagging for regression problems?\n\nYes, Bagging can be used for regression. Instead of majority voting, it takes the average of predictions.\n\n2. What is the difference between multiple model training and single model training?\nSingle model → only one model is trained\nMultiple model → many models are trained and combined for better performance\n\n3. Explain the concept of feature randomness in Random Forest\n\nRandom Forest selects random features for each tree, which helps reduce overfitting and improves performance.\n\n4. What is OOB (Out-of-Bag) Score?\n\nOOB score is a way to evaluate the model using data that was not used during training.\n\n5. How can you measure the importance of features in a Random Forest model?\n\nBy checking how much each feature contributes to prediction using feature importance scores.\n\n6. Explain the working principle of a Bagging Classifier\n\nIt trains multiple models on different random samples of data and combines their predic
# ...

# %%
#21. Train a Bagging Classifier using Decision Trees on a sample dataset and print model accuracy
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

data = load_iris()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y)

model = BaggingClassifier(DecisionTreeClassifier(), n_estimators=10)
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 0.9736842105263158

# %%
#22. Train a Bagging Regressor using Decision Trees and evaluate using Mean Squared Error (MSE)
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

model = BaggingRegressor(DecisionTreeRegressor(), n_estimators=10)
model.fit(X_train, y_train)

pred = model.predict(X_test)
print(mean_squared_error(y_test, pred))
# Out:
# 0.031052631578947366

# %%
#23. Train a Random Forest Classifier on the Breast Cancer dataset and print feature importance scores
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()
X, y = data.data, data.target

model = RandomForestClassifier()
model.fit(X, y)

print(model.feature_importances_)
# Out:
# [0.02669806 0.0158818  0.02861586 0.07643923 0.0078993  0.01470851
#  0.0423366  0.0867081  0.0041755  0.00470205 0.01409843 0.00509198
#  0.0146127  0.03723635 0.00382926 0.00340302 0.00732163 0.00888301
#  0.00403756 0.00400871 0.12300257 0.01891288 0.13950962 0.11170111
#  0.01307147 0.01419602 0.0266965  0.12324452 0.01094845 0.00802919]

# %%
#24. Train a Random Forest Regressor and compare its performance with a single Decision Tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

dt = DecisionTreeRegressor()
rf = RandomForestRegressor()

dt.fit(X_train, y_train)
rf.fit(X_train, y_train)

print("DT:", dt.score(X_test, y_test))
print("RF:", rf.score(X_test, y_test))
# Out:
# DT: 0.9560693641618497
# RF: 0.9583361849710983

# %%
#25. Compute the Out-of-Bag (OOB) Score for a Random Forest Classifier
model = RandomForestClassifier(oob_score=True)
model.fit(X_train, y_train)

print(model.oob_score_)
# Out:
# 0.9464285714285714

# %%
#26. Train a Bagging Classifier using SVM as a base estimator and print accuracy
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

data = load_iris()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y)

model = BaggingClassifier(estimator=SVC(), n_estimators=10)
model.fit(X_train, y_train)

print("Accuracy:", model.score(X_test, y_test))
# Out:
# Accuracy: 0.9736842105263158

# %%
#27. Train a Random Forest Classifier with different numbers of trees and compare accuracy
from sklearn.ensemble import RandomForestClassifier

for n in [10, 50, 100]:
    model = RandomForestClassifier(n_estimators=n)
    model.fit(X_train, y_train)
    print("Trees:", n, "Accuracy:", model.score(X_test, y_test))
# Out:
# Trees: 10 Accuracy: 1.0
# Trees: 50 Accuracy: 1.0
# Trees: 100 Accuracy: 1.0

# %%
#28. Train a Bagging Classifier using Logistic Regression as a base estimator and print AUC score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

model = BaggingClassifier(estimator=LogisticRegression(), n_estimators=10)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("AUC:", roc_auc_score(y_test, y_pred))
# Out:
# C:\Users\sdaya\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 9
#       6 model.fit(X_train, y_train)
#       8 y_pred = model.predict(X_test)
# ----> 9 print("AUC:", roc_auc_score(y_test, y_pred))
#
# ...

# %%
#29. Train a Random Forest Regressor and analyze feature importance scores
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)

print("Feature Importance:", model.feature_importances_)
# Out:
# Feature Importance: [0.00820129 0.00974607 0.51367891 0.46837373]

# %%
#30. Train an ensemble model using both Bagging and Random Forest and compare accuracy.
bag = BaggingClassifier()
rf = RandomForestClassifier()

bag.fit(X_train, y_train)
rf.fit(X_train, y_train)

print("Bagging:", bag.score(X_test, y_test))
print("Random Forest:", rf.score(X_test, y_test))
# Out:
# Bagging: 1.0
# Random Forest: 1.0

# %%
#31. Train a Random Forest Classifier and tune hyperparameters using GridSearchCV
from sklearn.model_selection import GridSearchCV

params = {'n_estimators':[10,50], 'max_depth':[3,5]}
grid = GridSearchCV(RandomForestClassifier(), params)

grid.fit(X_train, y_train)
print(grid.best_params_)
# Out:
# {'max_depth': 5, 'n_estimators': 10}

# %%
#32. Train a Bagging Regressor with different numbers of base estimators and compare performance
from sklearn.ensemble import BaggingRegressor

for n in [5,10,20]:
    model = BaggingRegressor(n_estimators=n)
    model.fit(X_train, y_train)
    print(n, model.score(X_test, y_test))
# Out:
# 5 1.0
# 10 0.999654859218892
# 20 1.0

# %%
#33. Train a Random Forest Classifier and analyze misclassified samples
model = RandomForestClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

misclassified = X_test[y_test != y_pred]
print("Misclassified samples:", misclassified)
# Out:
# Misclassified samples: []

# %%
#34. Train a Bagging Classifier and compare its performance with a single Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
bag = BaggingClassifier()

dt.fit(X_train, y_train)
bag.fit(X_train, y_train)

print("DT:", dt.score(X_test, y_test))
print("Bagging:", bag.score(X_test, y_test))
# Out:
# DT: 1.0
# Bagging: 1.0

# %%
#35. Train a Random Forest Classifier and visualize the confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True)
# Out:
# <Axes: >

# %%
#36. Train a Stacking Classifier using Decision Trees, SVM, and Logistic Regression, and compare accuracy
from sklearn.ensemble import StackingClassifier

estimators = [
    ('dt', DecisionTreeClassifier()),
    ('svm', SVC()),
    ('lr', LogisticRegression())
]

model = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 1.0

# %%
#37. Train a Random Forest Classifier and print the top 5 most important features
import numpy as np

model = RandomForestClassifier()
model.fit(X_train, y_train)

importance = model.feature_importances_
top5 = np.argsort(importance)[-5:]

print("Top 5 features:", top5)
# Out:
# Top 5 features: [1 0 3 2]

# %%
#38. Train a Bagging Classifier and evaluate performance using Precision, Recall, and F1-score
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        15
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38

# %%
#39. Train a Random Forest Classifier and analyze the effect of max_depth on accuracy
for d in [2, 5, 10]:
    model = RandomForestClassifier(max_depth=d)
    model.fit(X_train, y_train)
    print("Depth:", d, model.score(X_test, y_test))
# Out:
# Depth: 2 1.0
# Depth: 5 1.0
# Depth: 10 1.0

# %%
#40. Train a Bagging Regressor using different base estimators (DecisionTree and KNeighbors) and compare performance
from sklearn.neighbors import KNeighborsRegressor

model1 = BaggingRegressor(estimator=DecisionTreeRegressor())
model2 = BaggingRegressor(estimator=KNeighborsRegressor())

model1.fit(X_train, y_train)
model2.fit(X_train, y_train)

print("DT:", model1.score(X_test, y_test))
print("KNN:", model2.score(X_test, y_test))
# Out:
# DT: 0.9982742960944596
# KNN: 0.9930971843778383

# %%
#41. Train a Random Forest Classifier and evaluate its performance using ROC-AUC Score
from sklearn.metrics import roc_auc_score

print(roc_auc_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 4
#       1 #41. Train a Random Forest Classifier and evaluate its performance using ROC-AUC Score
#       2 from sklearn.metrics import roc_auc_score
# ----> 4 print(roc_auc_score(y_test, y_pred))
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
# ...

# %%
#42. Train a Bagging Classifier and evaluate its performance using cross-validation
from sklearn.model_selection import cross_val_score

scores = cross_val_score(BaggingClassifier(), X, y, cv=5)
print(scores.mean())
# Out:
# 0.9466666666666667

# %%
#43. Train a Random Forest Classifier and plot the Precision-Recall curve
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

p, r, _ = precision_recall_curve(y_test, y_pred)
plt.plot(r, p)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 5
#       2 from sklearn.metrics import precision_recall_curve
#       3 import matplotlib.pyplot as plt
# ----> 5 p, r, _ = precision_recall_curve(y_test, y_pred)
#       6 plt.plot(r, p)
#       7 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
# ...
